# %% [markdown]
# # Healthcare Data Analytics: Patient Outcomes Analysis
# ### Digital Health & Analytics Portfolio Project 1
#
# This notebook contains the exploratory analysis pipeline for cardiovascular cohort assessment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('../data/heart.csv')
df.head()
